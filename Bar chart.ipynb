# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pickle

# %%
c= pd.read_csv("dataset_coding.csv")
nc= pd.read_csv("dataset full 7f.csv")

# %%
c
# Out:
#         Ficket score  CpG Island  GC Content  ORF Length  Transcript Length  \
# 0           2.179594        18.0   35.943468       978.0             2618.0
# 1           1.292320         8.0   46.006390       936.0              939.0
# 2           1.292320         8.0   46.006390       936.0              939.0
# 3           0.921371       302.0   69.927850      2532.0             3465.0
# 4           0.921663       302.0   69.925029      2535.0             3468.0
# ...              ...         ...         ...         ...                ...
# 111271      1.361842         6.0   43.097643       294.0              297.0
# 111272      1.312042        31.0   44.267054       297.0             1378.0
# 111273      1.319950        40.0   44.922737       198.0             1812.0
# 111274      2.085676         8.0   42.666667       369.0              525.0
# 111275      1.263617        35.0   46.275197       561.0             1141.0
#
#         ORF Ratio  AT Dinucletide  non-coding=0
# ...

# %%
c_fick = np.mean(c.iloc[:,0].values)
nc_fick = np.mean(nc.iloc[:,0].values)

# %%
c_cpg = np.mean(c.iloc[:,1].values)
nc_cpg = np.mean(nc.iloc[:,1].values)

# %%
c_gc = np.mean(c.iloc[:,2].values)
nc_gc = np.mean(nc.iloc[:,2].values)

# %%
c_orf = np.mean(c.iloc[:,3].values)
nc_orf = np.mean(nc.iloc[:,3].values)

# %%
c_tran = np.mean(c.iloc[:,4].values)
nc_tran = np.mean(nc.iloc[:,4].values)

# %%
c_orfrat = np.mean(c.iloc[:,5].values)
nc_orfrat = np.mean(nc.iloc[:,5].values)

# %%
c_atd = np.mean(c.iloc[:,6].values)
nc_atd = np.mean(nc.iloc[:,6].values)

# %%
ficket_sore
# Out:
# 1.5670727318290452

# %%
import pandas as pd
import matplotlib.pyplot as plt
types = ['']
coderna = c_fick
noncoderna = nc_fick

df = pd.DataFrame({'RNA': types,
                   'Coding RNA': coderna,
                   'Non Coding RNA': noncoderna})

ax = df.plot.bar(x='RNA', rot=0, figsize=(10, 8))
plt.xlabel('RNA')
plt.ylabel('Ficket Score')
# Out:
# Text(0, 0.5, 'Ficket Score')

# %%
import pandas as pd
import matplotlib.pyplot as plt
types = ['']
coderna = c_cpg
noncoderna = nc_cpg

df = pd.DataFrame({'RNA': types,
                   'Coding RNA': coderna,
                   'Non Coding RNA': noncoderna})

ax = df.plot.bar(x='RNA', rot=0, figsize=(10, 8))
plt.xlabel('RNA')
plt.ylabel('CPG')
# Out:
# Text(0, 0.5, 'CPG')

# %%
import pandas as pd
import matplotlib.pyplot as plt
types = ['']
coderna = c_gc
noncoderna = nc_gc

df = pd.DataFrame({'RNA': types,
                   'Coding RNA': coderna,
                   'Non Coding RNA': noncoderna})

ax = df.plot.bar(x='RNA', rot=0, figsize=(10, 8))
plt.xlabel('RNA')
plt.ylabel('GC')
# Out:
# Text(0, 0.5, 'GC')

# %%
import pandas as pd
import matplotlib.pyplot as plt
types = ['']
coderna = c_orf
noncoderna = nc_orf

df = pd.DataFrame({'RNA': types,
                   'Coding RNA': coderna,
                   'Non Coding RNA': noncoderna})

ax = df.plot.bar(x='RNA', rot=0, figsize=(10, 8))
plt.xlabel('RNA')
plt.ylabel('ORF')
# Out:
# Text(0, 0.5, 'ORF')

# %%
import pandas as pd
import matplotlib.pyplot as plt
types = ['']
coderna = c_tran
noncoderna = nc_tran

df = pd.DataFrame({'RNA': types,
                   'Coding RNA': coderna,
                   'Non Coding RNA': noncoderna})

ax = df.plot.bar(x='RNA', rot=0, figsize=(10, 8))
plt.xlabel('RNA')
plt.ylabel('Transcript Length')
# Out:
# Text(0, 0.5, 'Transcript Length')

# %%
import pandas as pd
import matplotlib.pyplot as plt
types = ['']
coderna = c_orfrat
noncoderna = nc_orfrat

df = pd.DataFrame({'RNA': types,
                   'Coding RNA': coderna,
                   'Non Coding RNA': noncoderna})

ax = df.plot.bar(x='RNA', rot=0, figsize=(10, 8))
plt.xlabel('RNA')
plt.ylabel('ORF RATIO')
# Out:
# Text(0, 0.5, 'ORF RATIO')

# %%
import pandas as pd
import matplotlib.pyplot as plt
types = ['']
coderna = c_atd
noncoderna = nc_atd

df = pd.DataFrame({'RNA': types,
                   'Coding RNA': coderna,
                   'Non Coding RNA': noncoderna})

ax = df.plot.bar(x='RNA', rot=0, figsize=(10, 8))
plt.xlabel('RNA')
plt.ylabel('AT Dinucletide')
# Out:
# Text(0, 0.5, 'AT Dinucletide')
